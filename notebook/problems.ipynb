# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %%
# Formuals for Normal Distribution 

from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

def bnorm(x, mean=0, sd=1):
    return norm.pdf(x, loc=mean, scale=sd)

def qnorm(q, mean=0, sd=1):
    return norm.cdf(q, loc=mean, scale=sd)

def rnorm(n, mean=0, sd=1):
    return norm.rvs(loc=mean, scale=sd, size=n)

def lnorm(p, mean=0, sd=1):
    return norm.ppf(p, loc=mean, scale=sd)

np.random.seed(42)

print(f"Probability that a normal dist (10, 0.2) takes the value 2: {bnorm(2, mean=10, sd=0.2)}")
print(f"Probability that a normal dist (10, 0.2) takes a value less than 2: {qnorm(2, mean=10, sd=0.2)}")
print(f"Value with cumulative probability 0.9 in normal dist (10, 0.2): {lnorm(0.9, mean=10, sd=0.2)}")
print(f"2000 random samples from normal dist (10, 0.2): {rnorm(2000, mean=10, sd=0.2)}")

mean = 10
sd = 0.2
data = rnorm(2000, mean=mean, sd=sd)

pmf = bnorm(data, mean=mean, sd=sd)
cdf = qnorm(data, mean=mean, sd=sd)
ppf = lnorm(norm.cdf(data, loc=mean, scale=sd), mean=mean, sd=sd)  # inverse of CDF

fig, axis = plt.subplots(3, 1, figsize=(6, 8))

axis[0].stem(data[:100], pmf[:100], linefmt="r-", basefmt=" ")
axis[0].set_title("PDF")

axis[1].stem(data[:100], cdf[:100], linefmt="b-", basefmt=" ")
axis[1].set_title("CDF")

axis[2].stem(data[:100], ppf[:100], linefmt="g-", basefmt=" ")
axis[2].set_title("PPF")

plt.tight_layout()
plt.show()

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Probability that a normal dist (10, 0.2) takes the value 2: 0.0
# Probability that a normal dist (10, 0.2) takes a value less than 2: 0.0
# Value with cumulative probability 0.9 in normal dist (10, 0.2): 10.25631031310892
# 2000 random samples from normal dist (10, 0.2): [10.09934283  9.97234714 10.12953771 ...  9.82362507  9.96738661
#   9.85101947]

# %%
# Formulas for uniform distributon 

from scipy.stats import uniform
import matplotlib.pyplot as plt
import numpy as np

def buniform(x, low = 0, high = 1):
    result = uniform.pdf(x, loc = low, scale = high)
    return result

def quniform(q, low = 0, high = 1):
    result = uniform.cdf(q, loc = low, scale = high)
    return result

def runiform(n, low = 0, high = 1):
    result = uniform.rvs(loc=low, scale=high, size=n)
    return result

def luniform(p, low = 0, high =1):
    result = uniform.ppf(p,loc=low, scale=high)
    return result

np.random.seed(42)

low = 0
high = 1
data = np.arange(-5, 5, 0.01)

pmf = buniform(data, low = low, high = high)
cdf = quniform(data, low = low, high = high)
ppf = luniform(data, low = low, high = high)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pmf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
